# %% [markdown]
# # Imort the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# # Importing the Data

# %%
df = pd.read_csv(r'C:\Users\santi\OneDrive\Documents\New jobs\Data sets\movies.csv')

# %% [markdown]
# Now we can look at the data.

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %% [markdown]
# We can use a for loop to see if there is any data missing from any of the columns.

# %%
for col in df.columns:
    pct_missing= np.mean(df[col].isnull())
    print ('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %% [markdown]
# There is no missing data. Next we will check what data type each columnis.

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %% [markdown]
# We can convert the votes into an integer as there isn't decimals of a vote

# %%
df['votes'] = df['votes'].astype('int64')

# %% [markdown]
# Now we will drop any duplicates in the table.

# %%
df=df.drop_duplicates()

# %% [markdown]
# # Correlations

# %% [markdown]
# We are going to see what different categories have an effect on the gross profit of a film. We can sort the titles by descending gross profit.

# %%
df.sort_values(by=['gross'], inplace =False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 3731                                      Avatar      PG-13  Action  2009
# 5302                           Avengers: Endgame      PG-13  Action  2019
# 1795                                     Titanic      PG-13   Drama  1997
# 4730  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5158                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3898                                 Tanner Hall          R   Drama  2009
# 1378                  Philadelphia Experiment II      PG-13  Action  1993
# 2286                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1920                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %% [markdown]
# We will create a scatter plot with budget vs gross.

# %%
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Film budget')
plt.ylabel('Gross Earnings')
plt.show()

# %% [markdown]
# Lets use a regression plot to work out if the two categories are correlated using seaborn

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# No we can see the correlation between all the numerical values

# %%
df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# There is a high correlation between gross and budget and a correlation between gross and votes we can use a heatmap to make this easier to visualise

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matrix For Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %% [markdown]
# The above correlations only work for numeric values. We can assign a numeric value to the non numeric features so we can more easily see any possible correlations correlations

# %%
df_numerised = df

for col_name in df_numerised.columns:
    if (df_numerised[col_name].dtype == 'object'):
        df_numerised[col_name] = df_numerised[col_name].astype('category')
        df_numerised[col_name] = df_numerised[col_name].cat.codes
df_numerised
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000       757    1818
# 3      204       4      4  1980      1127    7.7   221000       889    1413
# 4      732       6      4  1980      1170    7.3   108000       719     351
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5416   415       6      0  2020       904    6.6   140000        16    2390
# 5417  3556       4      0  2020       713    6.5   102000       852    2309
# 5418  1153       4      1  2020       904    5.6    53000      1809    2827
# 5419  3978       4      1  2020       758    6.8    42000       294    2091
# 5420  4090       3      0  2020       370    6.8     3700       746    1184
#
# ...

# %% [markdown]
# We can see that columns swhich were previously string int data types have been converted so the string has a numeric representation the numeric columns have been left the same

# %%
correlation_matrix = df_numerised.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matrix For Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerised.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %% [markdown]
# Now we can untack the data then  remove all the correlations below 0.5 to make it easier to read.

# %%
correlation_mat = df_numerised.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.029234
#          genre       0.010996
#          year        0.025542
#          released   -0.006152
#                        ...
# runtime  country    -0.034477
#          budget      0.318695
#          gross       0.275796
#          company     0.037585
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
high_corr = corr_pairs[(corr_pairs) > 0.5]
high_corr
# Out:
# name      name        1.000000
# rating    rating      1.000000
# genre     genre       1.000000
# year      year        1.000000
# released  released    1.000000
# score     score       1.000000
# votes     votes       1.000000
#           gross       0.614751
# director  director    1.000000
# writer    writer      1.000000
# star      star        1.000000
# country   country     1.000000
# budget    budget      1.000000
#           gross       0.740247
# gross     votes       0.614751
#           budget      0.740247
#           gross       1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %% [markdown]
# We can see that both votes and budget had an impact on the gross revenue
